# %%
from sklearn.datasets import make_moons

X, y = make_moons(10000, noise=0.4, random_state=0)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import GradientBoostingRegressor

X_train, X_val, y_train, y_val = train_test_split(X, y)

gbrt = GradientBoostingRegressor(max_depth=2, n_estimators=120)
gbrt.fit(X_train, y_train)

errors = [mean_squared_error(y_val, y_pred) for y_pred in gbrt.staged_predict(X_val)]
best_n_estimators = np.argmin(errors) + 1

gbrt_best = GradientBoostingRegressor(max_depth=2, n_estimators=best_n_estimators)
gbrt_best.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=2, n_estimators=np.int64(108))

# %%
best_n_estimators
# Out:
# np.int64(108)

# %%
import xgboost

xgb_reg = xgboost.XGBRegressor()
xgb_reg.fit(X_train, y_train)
y_pred = xgb_reg.predict(X_val)

# %%
xgb_reg.early_stopping_rounds = 2
xgb_reg.fit(X_train, y_train, eval_set=[(X_val, y_val)])
y_pred = xgb_reg.predict(X_val)
# Out:
# [0]	validation_0-rmse:0.41720
# [1]	validation_0-rmse:0.37092
# [2]	validation_0-rmse:0.34621
# [3]	validation_0-rmse:0.33359
# [4]	validation_0-rmse:0.32690
# [5]	validation_0-rmse:0.32443
# [6]	validation_0-rmse:0.32276
# [7]	validation_0-rmse:0.32237
# [8]	validation_0-rmse:0.32199
# [9]	validation_0-rmse:0.32185
# [10]	validation_0-rmse:0.32250
# [11]	validation_0-rmse:0.32292

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml("mnist_784")

# %%
X = mnist.data

# %%
y = mnist.target

# %%
type(X)
# Out:
# pandas.DataFrame

# %%
X_train = X.iloc[:50000, :]
X_test, X_val = X.iloc[50000:60000, :], X.iloc[60000:, :]

# %%
X_val
# Out:
#        pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 60000       0       0       0       0       0       0       0       0       0
# 60001       0       0       0       0       0       0       0       0       0
# 60002       0       0       0       0       0       0       0       0       0
# 60003       0       0       0       0       0       0       0       0       0
# 60004       0       0       0       0       0       0       0       0       0
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 69995       0       0       0       0       0       0       0       0       0
# 69996       0       0       0       0       0       0       0       0       0
# 69997       0       0       0       0       0       0       0       0       0
# 69998       0       0       0       0       0       0       0       0       0
# 69999       0       0       0       0       0       0       0       0       0
#
# ...

# %%
y_train, y_test, y_val = y[:50000], y[50000:60000], y[60000:]

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import SVC

rf_clf = RandomForestClassifier()
et_clf = ExtraTreesClassifier()
svm_clf = SVC(probability=True)

# %%
for classifier in (rf_clf, et_clf, svm_clf):
    classifier.fit(X_train, y_train)

# %%
y_pred = []

for classifier in (rf_clf, et_clf, svm_clf):
    y_pred.append(classifier.predict(X_val))

# %%
from sklearn.metrics import accuracy_score

for y_pred_sing in y_pred:
    print(accuracy_score(y_val, y_pred_sing))
# Out:
# 0.9694
# 0.9718
# 0.9785

# %%
y_pred
# Out:
# [array(['7', '2', '1', ..., '4', '5', '6'], shape=(10000,), dtype=object),
#  array(['7', '2', '1', ..., '4', '5', '6'], shape=(10000,), dtype=object),
#  array(['7', '2', '1', ..., '4', '5', '6'], shape=(10000,), dtype=object)]

# %%
accuracy_score(y_pred[2], y_val)
len(y_pred[0])
# Out:
# 10000

# %%
predictions_int = [arr.astype(int) for arr in y_pred]
preds = np.vstack(predictions_int)

# %%
preds
# Out:
# array([[7, 2, 1, ..., 4, 5, 6],
#        [7, 2, 1, ..., 4, 5, 6],
#        [7, 2, 1, ..., 4, 5, 6]], shape=(3, 10000))

# %%
from scipy.stats import mode
majority_voted, _ = mode(preds, axis=0, keepdims=False)

# %%
majority_voted
# Out:
# array([7, 2, 1, ..., 4, 5, 6], shape=(10000,))

# %%
accuracy_score(y_val.astype(int), majority_voted)
# Out:
# 0.9749

# %%
y_val.astype(int)
# Out:
# 60000    7
# 60001    2
# 60002    1
# 60003    0
# 60004    4
#         ..
# 69995    2
# 69996    3
# 69997    4
# 69998    5
# 69999    6
# Name: class, Length: 10000, dtype: int64

# %%
for i in range(0, len(preds[0])):
    for j in range(0, preds[0][j]):
        sum = preds[0][j] + preds[1][j] + preds[2][j]

# %%
#Solutions
from sklearn.model_selection import train_test_split
X_train_val, X_test, y_train_val, y_test = train_test_split(mnist.data, mnist.target, test_size=10000, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=10000, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.svm import LinearSVC
from sklearn.neural_network import MLPClassifier

random_forest_clf = RandomForestClassifier(n_estimators=100, random_state=42)
extra_trees_clf = ExtraTreesClassifier(n_estimators=100, random_state=42)
svm_clf = LinearSVC(max_iter=100, tol=20, random_state=42)
mlp_clf = MLPClassifier(random_state=42)

# %%
estimators = [random_forest_clf, extra_trees_clf, svm_clf, mlp_clf]
for estimator in estimators:
    print("Training the", estimator)
    estimator.fit(X_train, y_train)
# Out:
# Training the RandomForestClassifier(random_state=42)
# Training the ExtraTreesClassifier(random_state=42)
# Training the LinearSVC(max_iter=100, random_state=42, tol=20)
# Training the MLPClassifier(random_state=42)

# %%
[estimator.score(X_val, y_val) for estimator in estimators]
# Out:
# [0.9692, 0.9715, 0.0997, 0.9627]

# %%
from sklearn.ensemble import VotingClassifier
named_estimators = [
    ("random_forest_clf", random_forest_clf),
    ("extra_trees_clf", extra_trees_clf),
    ("svm_clf", svm_clf),
    ("mlp_clf", mlp_clf),
]

voting_clf = VotingClassifier(named_estimators)

# %%
voting_clf.fit(X_train, y_train)
# Out:
# VotingClassifier(estimators=[('random_forest_clf',
#                               RandomForestClassifier(random_state=42)),
#                              ('extra_trees_clf',
#                               ExtraTreesClassifier(random_state=42)),
#                              ('svm_clf',
#                               LinearSVC(max_iter=100, random_state=42, tol=20)),
#                              ('mlp_clf', MLPClassifier(random_state=42))])

# %%
voting_clf.score(X_val, y_val)
# Out:
# 0.9706

# %%
del voting_clf.estimators_[2]

# %%
voting_clf.score(X_val, y_val)
# Out:
# 0.973

# %%
import numpy as np

X_val_predictions = np.empty((len(X_val), len(estimators)), dtype=np.float32)
for index, estimator in enumerate(estimators):
    X_val_predictions[:, index] = estimator.predict(X_val)

# %%
X_val_predictions
# Out:
# array([[5., 5., 5.],
#        [8., 8., 8.],
#        [2., 2., 2.],
#        ...,
#        [7., 7., 7.],
#        [6., 6., 6.],
#        [7., 7., 7.]], shape=(10000, 3), dtype=float32)

# %%
rnd_forest_blender = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)
rnd_forest_blender.fit(X_val_predictions, y_val)
# Out:
# RandomForestClassifier(n_estimators=200, oob_score=True, random_state=42)

# %%
rnd_forest_blender.oob_score_
# Out:
# 0.9695

# %%
X_test_predictions = np.empty((len(X_test), len(estimators)), dtype=np.float32)

for index, estimator in enumerate(estimators):
    X_test_predictions[:, index] = estimator.predict(X_test)

# %%
y_pred = rnd_forest_blender.predict(X_test_predictions)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9678
